# %%
# !pip install openai
# Out:
# zsh:1: command not found: pip

# %%
import pandas as pd
from openai import OpenAI
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 from openai import OpenAI
#       3 import os
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Set your OpenAI API key
OpenAI.api_key = os.environ["OPENAI_API_KEY"]

# %%
# Function to get sentiment analysis from OpenAI
def get_sentiment(text):
    client = OpenAI()

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "system",
                "content": [
                    {
                        "type": "text",
                        "text": "You will be provided with a text from a research journal discussing chatgpt in nursing, and your task is to classify its sentiment as positive, neutral, or negative."
                    }
                ]
            },
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": text
                    }
                ]
            }
        ],
        temperature=0,
        max_tokens=256,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )

    # Extract the sentiment from the response
    return response.choices[0].message.content

# %%
# Load the text to analyze
data = pd.read_excel('scraped_text_v1.xlsx')
data.head()
# Out:
#                                                Title  \
# 0  ChatGPT – A Systematic Review of Published Res...
# 1  ChatGPT in nursing education: opportunities an...
# 2                   Teaching and Learning in Nursing
# 3  GPTs are GPTs: An Early Look at the Labor Mark...
# 4  An Overview of the Evolution and Impact of Cha...
#
#                                               Author  \
# 0         Alin ZAMFIROIU, Denisa VASILE, Daniel SAVU
# 1                    Ponrathi Athilingam, Hong-Gu He
# 2                    Ponrathi Athilingam, Hong-Gu He
# 3  Tyna Eloundou, Sam Manning, Pamela Mishkin, Da...
# 4  Ankar Tersoo Catherine, S. K. Towfek, Abdelazi...
#
#                                             Keywords  \
# 0          ChatGPT, OpenAI, Papers, Research, Review
# 1  Artificial intelligence, Challenges, ChatGPT, ...
# 2  Artificial intelligence, Challenges, ChatGPT, ...
# 3  GPT, Labor Market, Large Language Models, Auto...
# ...

# %%
# Apply the sentiment analysis function to the text column
data['Sentiment'] = data['Text'].apply(get_sentiment)

# Display the results
print(data[['Text', 'Sentiment']])
# Out:
#                                                  Text  \
# 0   Informatica Economică vol. 27, no. 1/2023 \n \...
# 1   Computer Methods and Programs in Biomedicine 2...
# 2   Full Length Article\nChatGPT in nursing educat...
# 3   WORKING PAPER\nGPTs are GPTs: An Early Look at...
# 4    \n \n \n*Corresponding author. Email: ankartr...
# 5   Vol:.(1234567890)\nAnnals of Biomedical Engine...
# 6   Nurse Education Today 127 (2023) 105835\nAvail...
# 7   International Forum of Educational Technology ...
# 8   1\nThe Ethics of ChatGPT in Medicine and\nHeal...
# 9   Citation: Sallam, M. ChatGPT Utility\nin Healt...
# 10  International Journal of Nursing Studies Advan...
# 11  What if your patient switches from Dr. Google ...
# 12  Full Terms & Conditions of access and use can ...
# 13  Viewpoint\nEthical Considerations of Using Cha...
# 14  JMRHS 7 (2), 3028−3032 (2024)                 ...
# 15  Full Terms & Conditions of access and use can ...
# ...

# %%
data.head()
# Out:
#                                                Title  \
# 0  ChatGPT – A Systematic Review of Published Res...
# 1  ChatGPT in nursing education: opportunities an...
# 2                   Teaching and Learning in Nursing
# 3  GPTs are GPTs: An Early Look at the Labor Mark...
# 4  An Overview of the Evolution and Impact of Cha...
#
#                                               Author  \
# 0         Alin ZAMFIROIU, Denisa VASILE, Daniel SAVU
# 1                    Ponrathi Athilingam, Hong-Gu He
# 2                    Ponrathi Athilingam, Hong-Gu He
# 3  Tyna Eloundou, Sam Manning, Pamela Mishkin, Da...
# 4  Ankar Tersoo Catherine, S. K. Towfek, Abdelazi...
#
#                                             Keywords  \
# 0          ChatGPT, OpenAI, Papers, Research, Review
# 1  Artificial intelligence, Challenges, ChatGPT, ...
# 2  Artificial intelligence, Challenges, ChatGPT, ...
# 3  GPT, Labor Market, Large Language Models, Auto...
# ...
